# %%
import pandas as pd

# %%
# !pip install xlrd

# %%
try:
    excel_file = "BFYGA1P1_QQ4V.XLS"
    # Using xlrd engine for .xls files
    df = pd.read_excel(excel_file, sheet_name=None, engine='xlrd')
    print("Sheet names in the Excel file:")
    print(df.keys())
except FileNotFoundError:
    print(f"Error: The file '{excel_file}' was not found. Make sure the file exists in the same directory as this notebook.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
    print("\nNote: For .XLS files (older Excel format), you need to install the 'xlrd' package.")
    print("You can install it by running: pip install xlrd")
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
# Sheet names in the Excel file:
# dict_keys(['Sheet 1'])

# %%
# Access Sheet 1 from the dictionary of dataframes
sheet1_df = df['Sheet 1']

# Display basic information about the dataset
print("Dataset Info:")
print("-" * 50)
sheet1_df.info()

print("\nFirst few rows of the dataset:")
print("-" * 50)
print(sheet1_df.head())

print("\nBasic statistics of numerical columns:")
print("-" * 50)
print(sheet1_df.describe())
# Out:
# Dataset Info:
# --------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Item              73 non-null     float64
#  1   Invoice No        74 non-null     object
#  2   Product Title     74 non-null     object
#  3   Model Code        74 non-null     object
#  4   Spec Code         74 non-null     object
#  5   Parts No          74 non-null     object
#  6   Parts Name        74 non-null     object
#  7   Net Weight(Kg)    74 non-null     float64
#  8   Gross Weight(Kg)  74 non-null     float64
#  9   Quantity          74 non-null     int64
#  10  Amount(USD)       74 non-null     int64
#  11  Form Flag         74 non-null     object
#  12  HS Code           74 non-null     object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 7.6+ KB
#
# First few rows of the dataset:
# ...

# %%
# Create a new dataframe with only FORM-D entries
try:
    # Check if the column exists (we'll make this case-insensitive)
    form_flag_col = next(col for col in sheet1_df.columns if 'form' in col.lower() and 'flag' in col.lower())
    
    # Filter the dataframe to get only FORM-D entries
    form_d_df = sheet1_df[sheet1_df[form_flag_col].str.upper() == 'FORM-D']
    
    print(f"Number of FORM-D entries found: {len(form_d_df)}")
    print("\nFirst few rows of FORM-D entries:")
    print("-" * 50)
    print(form_d_df.head())
    
    # Display the columns in the filtered dataframe
    print("\nColumns in the filtered dataframe:")
    print("-" * 50)
    print(form_d_df.columns.tolist())
    
except StopIteration:
    print("Could not find a column related to form flag. Available columns are:")
    print(sheet1_df.columns.tolist())
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# Number of FORM-D entries found: 67
#
# First few rows of FORM-D entries:
# --------------------------------------------------
#    Item Invoice No                                      Product Title  \
# 0   1.0   BFYGA1P1  COMPONENT PARTS FOR YAMAHA MOTOR CYCLE        ...
# 1   2.0   BFYGA1P1  COMPONENT PARTS FOR YAMAHA MOTOR CYCLE        ...
# 2   3.0   BFYGA1P1  COMPONENT PARTS FOR YAMAHA MOTOR CYCLE        ...
# 4   5.0   BFYGA1P1  COMPONENT PARTS FOR YAMAHA MOTOR CYCLE        ...
# 5   6.0   BFYGA1P1  COMPONENT PARTS FOR YAMAHA MOTOR CYCLE        ...
#
#   Model Code Spec Code         Parts No                      Parts Name  \
# 0     B17GB2      010A  1PA-E2117-00     RET.,VALVE SPRING
# 1     B17GB2      010A  1PA-E2119-00     SEAL, VALVE STEM OIL
# 2     B17GB2      010A  1PA-E2231-00     GUIDE,STOPPER 1
# 4     B17GB2      010A  1PA-E6357-00     ROD,PUSH
# 5     B17GB2      010A  1PA-E8531-00     BAR,SHIFT FORK GUIDE 1
#
# ...
